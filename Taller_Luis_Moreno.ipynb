# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as st
from scipy.optimize import minimize

# %% [markdown]
# Taller confiabilidad
#
#  1.
#
#
#
#  mu= 1.5
#
#
#  sigma= 0.5

# %%
mu = 1.5
sigma = 0.5
normal = st.norm(loc=mu, scale=sigma)
# Grafiquemos esta distribución cerca del 0
xs = np.linspace(-5, 5, 1000)
ys = normal.pdf(xs)
fig, ax = plt.subplots(facecolor=(1, 1, 1))
ax.plot(xs, ys)
ax.grid(True)

# %% [markdown]
# Valores de a y b
#
# a= 0.5
#
# b=4

# %%
a = 0.5
b = 4

ax.fill_between(xs, ys, where=(a <= xs)&(xs <= b), color='orange', alpha=0.5)
fig

# %%
prob = normal.cdf(b) - normal.cdf(a)
# Agreguemos esta info a nuestro gráfico de antes
ax.annotate('area = {0:.2g}'.format(prob), xy =(1, 0.1),
                xytext =(2, 0.3),
                arrowprops = dict(facecolor ='skyblue',
                                  shrink = 0.005))
print("Supongamos que X está distribuida según una normal con mu={} y sigma={}.\
      \n Entonces la probabilidad de que X esté entre a={} y b={} es {:.2g}".format(mu, sigma, a, b, prob))
fig
# Out:
# Supongamos que X está distribuida según una normal con mu=1.5 y sigma=0.5.
#  Entonces la probabilidad de que X esté entre a=0.5 y b=4 es 0.98

# %% [markdown]
# Valores de a y b
#
# a= 0
#
# b= 30

# %%
a = 0
b = 30

ax.fill_between(xs, ys, where=(a <= xs)&(xs <= b), color='orange', alpha=0.5)
fig

# %%
prob = normal.cdf(b) - normal.cdf(a)
# Agreguemos esta info a nuestro gráfico de antes
ax.annotate('area = {0:.2g}'.format(prob), xy =(1, 0.1),
                xytext =(2, 0.3),
                arrowprops = dict(facecolor ='skyblue',
                                  shrink = 0.005))
print("Supongamos que X está distribuida según una normal con mu={} y sigma={}.\
      \n Entonces la probabilidad de que X esté entre a={} y b={} es {:.2g}".format(mu, sigma, a, b, prob))
fig
# Out:
# Supongamos que X está distribuida según una normal con mu=1.5 y sigma=0.5.
#  Entonces la probabilidad de que X esté entre a=0 y b=30 es 1

# %% [markdown]
# 2.
#
# mu= 5
#
# sigma= 0.5

# %%
mu = 5
sigma = 0.5
normal = st.norm(loc=mu, scale=sigma)
# Grafiquemos esta distribución cerca del 0
xs = np.linspace(0, 10, 1000)
ys = normal.pdf(xs)
fig, ax = plt.subplots(facecolor=(1, 1, 1))
ax.plot(xs, ys)
ax.grid(True)

# %% [markdown]
# Valores de a y b
#
# a= 0.5
#
# b=4

# %%
a = 0.5
b = 4

ax.fill_between(xs, ys, where=(a <= xs)&(xs <= b), color='orange', alpha=0.5)
fig

# %%
prob = normal.cdf(b) - normal.cdf(a)
# Agreguemos esta info a nuestro gráfico de antes
ax.annotate('area = {0:.2g}'.format(prob), xy =(3.5, 0.1),
                xytext =(2, 0.3),
                arrowprops = dict(facecolor ='skyblue',
                                  shrink = 0.005))
print("Supongamos que X está distribuida según una normal con mu={} y sigma={}.\
      \n Entonces la probabilidad de que X esté entre a={} y b={} es {:.2g}".format(mu, sigma, a, b, prob))
fig
# Out:
# Supongamos que X está distribuida según una normal con mu=5 y sigma=0.5.
#  Entonces la probabilidad de que X esté entre a=0.5 y b=4 es 0.023

# %% [markdown]
# Valores de a y b
#
# a= 0
#
# b=30

# %%
a = 0
b = 30

ax.fill_between(xs, ys, where=(a <= xs)&(xs <= b), color='orange', alpha=0.5)
fig

# %%
prob = normal.cdf(b) - normal.cdf(a)
# Agreguemos esta info a nuestro gráfico de antes
ax.annotate('area = {0:.2g}'.format(prob), xy =(3.5, 0.1),
                xytext =(2, 0.3),
                arrowprops = dict(facecolor ='skyblue',
                                  shrink = 0.005))
print("Supongamos que X está distribuida según una normal con mu={} y sigma={}.\
      \n Entonces la probabilidad de que X esté entre a={} y b={} es {:.2g}".format(mu, sigma, a, b, prob))
fig
# Out:
# Supongamos que X está distribuida según una normal con mu=5 y sigma=0.5.
#  Entonces la probabilidad de que X esté entre a=0 y b=30 es 1
